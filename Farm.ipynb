# %%
import locale
locale.setlocale(locale.LC_ALL, '')  # Use '' for auto, or force e.g. to 'en_US.UTF-8'
# Out:
# 'en_US.UTF-8'

# %%
interest = 1.068 # 6% interest
revenue = 364000 # 720,000 revenue per year
profit = 0.15 * revenue # % margins on revenue

owed = 420000 # mortage amount

print("interest:", interest - 1)
print("yearly revenue:", '{:n}'.format(revenue))
print("yearly profit:", '{:n}'.format(profit))
# Out:
# interest: 0.06800000000000006
# yearly revenue: 364,000
# yearly profit: 54,600

# %%
for x in range(1, 25):
    
    owed = owed - profit
    
    if owed <= 0:
        print("loan free in year: ", x)
        break
        
    owed = owed * interest
    
    print("end of year: ", x)
    print("amt owed: ", owed)
    print("\n")
# Out:
# end of year:  1
# amt owed:  390247.2
#
#
# end of year:  2
# amt owed:  358471.20960000006
#
#
# end of year:  3
# amt owed:  324534.4518528001
#
#
# end of year:  4
# amt owed:  288289.9945787905
#
#
# end of year:  5
# amt owed:  249580.91421014827
#
#
# end of year:  6
# amt owed:  208239.61637643835
#
#
# end of year:  7
# amt owed:  164087.11029003616
#
#
# end of year:  8
# amt owed:  116932.23378975863
#
#
# end of year:  9
# amt owed:  66570.82568746222
#
#
# end of year:  10
# amt owed:  12784.841834209648
#
#
# loan free in year:  11

# %%
possible_interest_rates = [(1 + (x / 100)) for x in range(6, 10)]
for i in possible_interest_rates:
    print("possible interest rate (%):", int((i - 1) * 100))
# Out:
# possible interest rate (%): 6
# possible interest rate (%): 7
# possible interest rate (%): 8
# possible interest rate (%): 9

# %%
revenues = [x * 30000 for x in range(1, 20)]
for revenue in revenues:
    print('${:n}'.format(revenue))
# Out:
# $30,000
# $60,000
# $90,000
# $120,000
# $150,000
# $180,000
# $210,000
# $240,000
# $270,000
# $300,000
# $330,000
# $360,000
# $390,000
# $420,000
# $450,000
# $480,000
# $510,000
# $540,000
# $570,000

# %%
combos = []

for interest in possible_interest_rates:
    for revenue in revenues:

        interest = interest # 6% interest
        revenue = revenue # 720,000 revenue per year
        profit_percentage = 0.18 # 10% profit
        owed = 420000 # mortage amount
        threshold = 15

        for x in range(1, 50):

            profit = profit_percentage * revenue # % margins on revenue
            owed = owed - profit

            if owed <= 0 and x <= threshold:
                combos.append((interest, revenue, x))
                print("loan free in year: ", x)
                break

            owed = owed * interest
# Out:
# loan free in year:  14
# loan free in year:  12
# loan free in year:  10
# loan free in year:  9
# loan free in year:  8
# loan free in year:  8
# loan free in year:  7
# loan free in year:  6
# loan free in year:  6
# loan free in year:  6
# loan free in year:  5
# loan free in year:  5
# loan free in year:  15
# loan free in year:  13
# loan free in year:  11
# loan free in year:  10
# loan free in year:  9
# loan free in year:  8
# loan free in year:  7
# loan free in year:  7
# loan free in year:  6
# loan free in year:  6
# loan free in year:  5
# loan free in year:  5
# loan free in year:  14
# loan free in year:  12
# loan free in year:  10
# loan free in year:  9
# loan free in year:  8
# loan free in year:  7
# loan free in year:  7
# loan free in year:  6
# loan free in year:  6
# loan free in year:  6
# loan free in year:  5
# loan free in year:  15
# loan free in year:  12
# loan free in year:  11
# loan free in year:  9
# loan free in year:  8
# loan free in year:  8
# ...

# %%
print("possible combinations that let you even out in year:", threshold, "\n")

for tup in combos:
    print("interest:", (tup[0] - 1) * 100)
    print("revenue:", '{:n}'.format(tup[1]))
    print("average yearly profit:", '${:n}'.format(tup[1] * profit_percentage))
    print("break even year:", tup[2])
    print("\n")
# Out:
# possible combinations that let you even out in year: 15
#
# interest: 6.000000000000005
# revenue: 240,000
# average yearly profit: $43,200
# break even year: 14
#
#
# interest: 6.000000000000005
# revenue: 270,000
# average yearly profit: $48,600
# break even year: 12
#
#
# interest: 6.000000000000005
# revenue: 300,000
# average yearly profit: $54,000
# break even year: 10
#
#
# interest: 6.000000000000005
# revenue: 330,000
# average yearly profit: $59,400
# break even year: 9
#
#
# interest: 6.000000000000005
# revenue: 360,000
# average yearly profit: $64,800
# break even year: 8
#
#
# interest: 6.000000000000005
# revenue: 390,000
# average yearly profit: $70,200
# break even year: 8
#
#
# interest: 6.000000000000005
# revenue: 420,000
# average yearly profit: $75,600
# break even year: 7
#
#
# interest: 6.000000000000005
# revenue: 450,000
# average yearly profit: $81,000
# break even year: 6
#
#
# interest: 6.000000000000005
# revenue: 480,000
# ...

# %%
import random

N = 1000000

revenues = []
years = []


for i in range(0, N):

    random_revenue = random.randint(10000, 500000)


    interest = 1.068 # 6% interest
    revenue = random_revenue # 720,000 revenue per year
    profit_percentage = 0.18 # 10% profit
    owed = 420000 # mortage amount
    threshold = 300

    for x in range(1, 300):

        profit = profit_percentage * revenue # % margins on revenue
        owed = owed - profit

        if owed <= 0 and x <= threshold:
            revenues.append(profit_percentage * revenue)
            years.append(x)
    #         print("loan free in year: ", x)
            break

        owed = owed * interest

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.scatter(revenues, years)
plt.show()

# %%
plt.figure(figsize=(2, 2))
display(plt.plot(revenues, years))
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# /usr/local/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py in draw_path(self, gc, path, transform, rgbFace)
#     160             try:
# --> 161                 self._renderer.draw_path(gc, path, transform, rgbFace)
#     162             except OverflowError as err:
#
# OverflowError: In draw_path: Exceeded cell block limit
#
# The above exception was the direct cause of the following exception:
#
# OverflowError                             Traceback (most recent call last)
# /usr/local/lib/python3.9/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ...
